# %% [markdown]
# # Python 101- matplotlib 繪圖
# ###### Jing-Hui Tong 2022/06/17

# %% [markdown]
# ### extra
# * [linestyle](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)
# * [marker](https://matplotlib.org/stable/api/markers_api.html)
# * [color](https://matplotlib.org/2.1.1/gallery/color/named_colors.html)
# * [legend location](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(-1,1,50) ### -1~1之間取50個點
y = x**2

# %%
plt.figure(figsize=(6,4))
plt.plot(x,y,color='red',linewidth=2, label='$x^2$')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(x, y, color='blue', linewidth=5, linestyle="--")


plt.xlabel('X',fontsize=15)
plt.ylabel('Y',fontsize=15)
plt.title('Function: Y=$x^2$')
plt.xticks(np.arange(-1,1.4, 0.2))

# plt.xlim(-1,1)
# plt.ylim(-0.5,4)

# plt.grid()

# plt.grid(axis='x')

plt.show()

# %%
plt.plot(x, y, color="red", marker='o',ls='-')

# %%
plt.scatter(x, y, color="g", marker='o', s=3)

# %%
plt.figure(figsize=(10,4))

x=np.linspace(0,10,100)

plt.subplot(121)
plt.plot(x,np.sin(x),color='green',linestyle="--")
plt.xlim(0,10)
plt.ylim(-2,1.2)

plt.subplot(122)
y=np.sin(x)+np.cos(2*x)
plt.plot(x,y,color='green',linestyle="--")
plt.xlim(0,10)
plt.ylim(-2,1.2)
# Out:
# (-2.0, 1.2)

# %% [markdown]
# ### Long Partice!
# #### please use the file: 41586_2022_4672_MOESM4_ESM.csv
# * Fig. 3 from Licciardi et al. (2022) Instantaneous tracking of earthquake growth with elastogravity signals

# %% [markdown]
# ![Screen Shot 2022-06-17 at 12.13.19 PM.png](attachment:681e8c09-d65b-42e4-b552-68994bd568ae.png)

# %% [markdown]
# * Hint
#
# 1. pd.read_csv
#
# 2. fig, ax= plt.subplots(3, 1, gridspec_kw={'height_ratios': [1, 1, 3]})
#
# 3. ax[0].plot
#
# 4. plt.title or plt.suptitle

# %%
## write down !
